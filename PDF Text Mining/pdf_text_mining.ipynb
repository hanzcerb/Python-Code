# %% [markdown]
# # Text Pre-Processing

# %% [markdown]
# ## 1. Import Libraries
# Below the common library that will be used in this task

# %%
import pdfminer
import re
import pandas as pd
import itertools

# %% [markdown]
# Below the library that will be used to download the file from GoogleDrive

# %%
# Libraries for Download the files
import io
import os
import google.auth
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
from googleapiclient.errors import HttpError

# %% [markdown]
# ## 2. Extract The Links
# To proceed, first we need to extract the information of the given pdf file, using pdfminer we can convert the pdf file to text file.

# %%
# source: Tutor class
# !pdf2txt.py -o task_2.txt google_drive_links.pdf
print("done")
# Out:
# done

# %% [markdown]
# Above code will generate a text file named "task_2.txt"
#
# After that, we can open the new generated text file to get the url for each given research pdf, and convert that to pdf

# %%
with open("task_2.txt", 'r') as pdf_txt:
    # pattern for each line
    pat = r'[\w\d\.]+ [\S]+'
    # find all pattern, for each data split by " "
    rows = [row.split(" ") for row in re.findall(pat, pdf_txt.read())]
    
df_t2_url = pd.DataFrame(rows, columns = ['filename', 'url'])

# %%
print(df_t2_url.shape)
df_t2_url.head()
# Out:
# (200, 2)
#      filename                                                url
# 0  PP3167.pdf  https://drive.google.com/uc?export=download&id...
# 1  PP3210.pdf  https://drive.google.com/uc?export=download&id...
# 2  PP3213.pdf  https://drive.google.com/uc?export=download&id...
# 3  PP3248.pdf  https://drive.google.com/uc?export=download&id...
# 4  PP3285.pdf  https://drive.google.com/uc?export=download&id...

# %% [markdown]
# ## 3. Downloaded Files
# To download the file first we need to configure about the API for google drive, which i will not explain here, after you finished setting up the API you can download a json file that contain everything about the necessary key to interact with the API. my json file named "endless-sol-308511-fff70d278fb0.json"
#
# Then we need to iterate for each links that we have from the dataframe, hence, we can download the file by using the url ID
#
# Every files that being downloaded will be safed inside `files/` path

# %%
def download_files(df):
    # Folder name where the pdf files will be stored
    folder_n = "files"
    
    # Check for the existant of folder
    if not os.path.exists(folder_n):
        os.makedirs(folder_n)
    
    # Set up the Drive API credentials
    creds, _ = google.auth.load_credentials_from_file("endless-sol-308511-fff70d278fb0.json")

    # Set up the Drive API client
    service = build("drive", "v3", credentials=creds)
    
    # Loop for every rows to get each links
    for idx, row in df.iterrows():
        # Set the ID of the file to download, the sequence after 'id=' in the url
        file_id = re.search(r'(?<=id=)[\S]+', row.url)[0]

        try:
            # Download the file contents
            request = service.files().get_media(fileId=file_id)
            file = io.BytesIO()
            downloader = MediaIoBaseDownload(file, request)
            done = False
            while done is False:
                status, done = downloader.next_chunk()
                print(f"{row.filename} download progress: {int(status.progress() * 100)}.")

            # Save the downloaded file to disk
            with open("files/" + row.filename, 'wb') as f:
                f.write(file.getbuffer())
            print(f"{row.filename} file downloaded successfully.")

        except HttpError as error:
            print(f"An error occurred for {row.filename}: {error}")
            file = None

# %%
# download files
download_files(df_t2_url)
# Out:
# PP3167.pdf download progress: 100.
# PP3167.pdf file downloaded successfully.
# PP3210.pdf download progress: 100.
# PP3210.pdf file downloaded successfully.
# PP3213.pdf download progress: 100.
# PP3213.pdf file downloaded successfully.
# PP3248.pdf download progress: 100.
# PP3248.pdf file downloaded successfully.
# PP3285.pdf download progress: 100.
# PP3285.pdf file downloaded successfully.
# PP3328.pdf download progress: 100.
# PP6969.pdf file downloaded successfully.
# PP6987.pdf download progress: 100.
# PP6987.pdf file downloaded successfully.
# PP7024.pdf download progress: 100.
# PP7024.pdf file downloaded successfully.
# PP7025.pdf download progress: 100.
# PP7025.pdf file downloaded successfully.
# PP7061.pdf download progress: 100.
# PP7061.pdf file downloaded successfully.
# PP7119.pdf download progress: 100.
# PP7119.pdf file downloaded successfully.
# PP7126.pdf download progress: 100.
# PP7126.pdf file downloaded successfully.
# PP7141.pdf download progress: 100.
# PP7141.pdf file downloaded successfully.
# PP7169.pdf download progress: 100.
# PP7169.pdf file downloaded successfully.
# PP7170.pdf download progress: 100.
# PP7170.pdf file downloaded successfully.
# PP7173.pdf download progress: 100.
# PP7173.pdf file downloaded successfully.
# PP7183.pdf download progress: 100.
# PP7183.pdf file downloaded successfully.
# PP7184.pdf download progress: 100.
# PP7184.pdf file downloaded successfully.
# PP7210.pdf download progress: 100.
# PP7210.pdf file downloaded successfully.
# PP7231.pdf download progress: 100.
# PP7231.pdf file downloaded successfully.
# PP7236.pdf download progress: 100.
# PP7236.pdf file downloaded successfully.
# PP7245.pdf download progress: 100.
# PP7245.pdf file downloaded successfully.
# PP7247.pdf download progress: 100.
# PP7247.pdf file downloaded successfully.
# PP7265.pdf download progress: 100.
# PP7265.pdf file downloaded successfully.

# %% [markdown]
# ## 4. Read Downloaded PDF files
# After finished downloading the file, we can read for every pdf file inside the `files/` and convert it into a text files that will also be saved in the same path

# %%
for idx, row in df_t2_url.iterrows():
    # use PDFminer to convert for each pdf file to txt files
    # !pdf2txt.py -o files\{row.filename}.txt files\{row.filename}
    print(f"{row.filename} has been converted to text file")
# Out:
# PP3167.pdf has been converted to text file
# PP3210.pdf has been converted to text file
# PP3213.pdf has been converted to text file
# PP3248.pdf has been converted to text file
# PP3285.pdf has been converted to text file
# PP3328.pdf has been converted to text file
# PP3377.pdf has been converted to text file
# PP3445.pdf has been converted to text file
# PP3470.pdf has been converted to text file
# PP3476.pdf has been converted to text file
# PP3513.pdf has been converted to text file
# PP3558.pdf has been converted to text file
# PP3579.pdf has been converted to text file
# PP3599.pdf has been converted to text file
# PP3617.pdf has been converted to text file
# PP3622.pdf has been converted to text file
# PP3653.pdf has been converted to text file
# PP3661.pdf has been converted to text file
# PP3693.pdf has been converted to text file
# PP3716.pdf has been converted to text file
# PP3723.pdf has been converted to text file
# PP3784.pdf has been converted to text file
# PP3796.pdf has been converted to text file
# PP3826.pdf has been converted to text file
# PP3834.pdf has been converted to text file
# PP3839.pdf has been converted to text file
# PP3845.pdf has been converted to text file
# PP3855.pdf has been converted to text file
# PP3863.pdf has been converted to text file
# PP3886.pdf has been converted to text file
# PP3887.pdf has been converted to text file
# PP3903.pdf has been converted to text file
# PP3910.pdf has been converted to text file
# PP3936.pdf has been converted to text file
# PP3942.pdf has been converted to text file
# PP3976.pdf has been converted to text file
# PP3990.pdf has been converted to text file
# PP4019.pdf has been converted to text file
# PP4024.pdf has been converted to text file
# PP4025.pdf has been converted to text file
# PP4040.pdf has been converted to text file
# PP4058.pdf has been converted to text file
# PP4080.pdf has been converted to text file
# PP4098.pdf has been converted to text file
# PP4184.pdf has been converted to text file
# PP4185.pdf has been converted to text file
# PP4257.pdf has been converted to text file
# PP4268.pdf has been converted to text file
# PP4299.pdf has been converted to text file
# PP4316.pdf has been converted to text file
# PP4318.pdf has been converted to text file
# PP4355.pdf has been converted to text file
# PP4363.pdf has been converted to text file
# PP4402.pdf has been converted to text file
# PP4407.pdf has been converted to text file
# PP4460.pdf has been converted to text file
# PP4500.pdf has been converted to text file
# PP4518.pdf has been converted to text file
# PP4538.pdf has been converted to text file
# PP4607.pdf has been converted to text file
# PP4615.pdf has been converted to text file
# PP4617.pdf has been converted to text file
# PP4625.pdf has been converted to text file
# PP4627.pdf has been converted to text file
# PP4640.pdf has been converted to text file
# PP4666.pdf has been converted to text file
# PP4677.pdf has been converted to text file
# PP4699.pdf has been converted to text file
# PP4710.pdf has been converted to text file
# PP4724.pdf has been converted to text file
# PP4836.pdf has been converted to text file
# PP4839.pdf has been converted to text file
# PP4840.pdf has been converted to text file
# PP4885.pdf has been converted to text file
# PP4889.pdf has been converted to text file
# PP4994.pdf has been converted to text file
# PP5003.pdf has been converted to text file
# PP5056.pdf has been converted to text file
# PP5058.pdf has been converted to text file
# PP5073.pdf has been converted to text file
# PP5106.pdf has been converted to text file
# PP5113.pdf has been converted to text file
# PP5116.pdf has been converted to text file
# PP5156.pdf has been converted to text file
# PP5159.pdf has been converted to text file
# PP5192.pdf has been converted to text file
# PP5198.pdf has been converted to text file
# PP5199.pdf has been converted to text file
# PP5200.pdf has been converted to text file
# PP5264.pdf has been converted to text file
# PP5271.pdf has been converted to text file
# PP5274.pdf has been converted to text file
# PP5290.pdf has been converted to text file
# PP5291.pdf has been converted to text file
# PP5295.pdf has been converted to text file
# PP5311.pdf has been converted to text file
# PP5322.pdf has been converted to text file
# PP5324.pdf has been converted to text file
# PP5360.pdf has been converted to text file
# PP5364.pdf has been converted to text file
# PP5385.pdf has been converted to text file
# PP5403.pdf has been converted to text file
# PP5460.pdf has been converted to text file
# PP5476.pdf has been converted to text file
# PP5479.pdf has been converted to text file
# PP5487.pdf has been converted to text file
# PP5534.pdf has been converted to text file
# PP5542.pdf has been converted to text file
# PP5571.pdf has been converted to text file
# PP5609.pdf has been converted to text file
# PP5621.pdf has been converted to text file
# PP5624.pdf has been converted to text file
# PP5631.pdf has been converted to text file
# PP5634.pdf has been converted to text file
# PP5667.pdf has been converted to text file
# PP5680.pdf has been converted to text file
# PP5694.pdf has been converted to text file
# PP5696.pdf has been converted to text file
# PP5708.pdf has been converted to text file
# PP5711.pdf has been converted to text file
# PP5715.pdf has been converted to text file
# PP5725.pdf has been converted to text file
# PP5729.pdf has been converted to text file
# PP5735.pdf has been converted to text file
# PP5736.pdf has been converted to text file
# PP5741.pdf has been converted to text file
# PP5760.pdf has been converted to text file
# PP5784.pdf has been converted to text file
# PP5822.pdf has been converted to text file
# PP5825.pdf has been converted to text file
# PP5827.pdf has been converted to text file
# PP5836.pdf has been converted to text file
# PP5845.pdf has been converted to text file
# PP5875.pdf has been converted to text file
# PP5886.pdf has been converted to text file
# PP5905.pdf has been converted to text file
# PP5918.pdf has been converted to text file
# PP5925.pdf has been converted to text file
# PP5932.pdf has been converted to text file
# PP5986.pdf has been converted to text file
# PP5992.pdf has been converted to text file
# PP6014.pdf has been converted to text file
# PP6035.pdf has been converted to text file
# PP6044.pdf has been converted to text file
# PP6061.pdf has been converted to text file
# PP6102.pdf has been converted to text file
# PP6119.pdf has been converted to text file
# PP6128.pdf has been converted to text file
# PP6193.pdf has been converted to text file
# PP6241.pdf has been converted to text file
# PP6263.pdf has been converted to text file
# PP6268.pdf has been converted to text file
# PP6310.pdf has been converted to text file
# PP6323.pdf has been converted to text file
# PP6366.pdf has been converted to text file
# PP6412.pdf has been converted to text file
# PP6437.pdf has been converted to text file
# PP6465.pdf has been converted to text file
# PP6468.pdf has been converted to text file
# PP6471.pdf has been converted to text file
# PP6480.pdf has been converted to text file
# PP6483.pdf has been converted to text file
# PP6510.pdf has been converted to text file
# PP6514.pdf has been converted to text file
# PP6553.pdf has been converted to text file
# PP6557.pdf has been converted to text file
# PP6597.pdf has been converted to text file
# PP6601.pdf has been converted to text file
# PP6613.pdf has been converted to text file
# PP6650.pdf has been converted to text file
# PP6666.pdf has been converted to text file
# PP6675.pdf has been converted to text file
# PP6743.pdf has been converted to text file
# PP6791.pdf has been converted to text file
# PP6874.pdf has been converted to text file
# PP6875.pdf has been converted to text file
# PP6881.pdf has been converted to text file
# PP6888.pdf has been converted to text file
# PP6917.pdf has been converted to text file
# PP6925.pdf has been converted to text file
# PP6954.pdf has been converted to text file
# PP6969.pdf has been converted to text file
# PP6987.pdf has been converted to text file
# PP7024.pdf has been converted to text file
# PP7025.pdf has been converted to text file
# PP7061.pdf has been converted to text file
# PP7119.pdf has been converted to text file
# PP7126.pdf has been converted to text file
# PP7141.pdf has been converted to text file
# PP7169.pdf has been converted to text file
# PP7170.pdf has been converted to text file
# PP7173.pdf has been converted to text file
# PP7183.pdf has been converted to text file
# PP7184.pdf has been converted to text file
# PP7210.pdf has been converted to text file
# PP7231.pdf has been converted to text file
# PP7236.pdf has been converted to text file
# PP7245.pdf has been converted to text file
# PP7247.pdf has been converted to text file
# PP7265.pdf has been converted to text file

# %% [markdown]
# There are several function below with function as follow:
# * `get_dir_file()` This function will read every text files inside the `files/` folder, and return the path for each text files
# * `finc_pattern()` This function accept text and pattern as the input, and will return the matched pattern using regex, will return None otherwise
# * `read_pdf_text()` This function will read the text file of pdf, and by using pattern, we could get file name, title, author, and body. This function will return a dataframe with the value of each information. This function will utulize both function above

# %%
def get_dir_file():
    dir_path = "files/"
    res = []
    # Iterate directory
    for path in os.listdir(dir_path):
        # check if current path is a file
        if os.path.isfile(os.path.join(dir_path, path)):
            # check whether it is text file or pdf file
            if path[-1] == "f":
                continue
            else:
                res.append(dir_path+path)
            # endif
        # endif
    # endfor
    return res

def find_pattern(text_f, pat):
    found = re.search(pat, text_f)
    if found:
        return found[0]
    else:
        return None

def read_pdf_text(dir_paths):
    # create an empty dictionary
    text_dict_lst = {}
    i = 0
    
    # loop for each directory path
    for path in dir_paths:
        # open the text file
        with open(path, "r", encoding="utf-8") as file:
            txt = file.read()
            # pattern for each factor
            file_n = path[6:-4]
            # take everything that ends with authored by
            title_pat = r'[\S\s]+(?=\sAuthored by:\s)'
            # take everything in between authored by and abstract
            auth_pat = r'(?<=\sAuthored by:\s)[\S\s]+(?=\sAbstract\s)'
            # take everything between abstract and paper body
            abs_pat = r'(?<=\sAbstract\s)[\S\s]+(?=\s1 Paper Body\s)'
            # take everything between paper body and references
            body_pat = r'(?<=\s1 Paper Body\s)[\S\s]+(?=\s2 References\s)'
            
            # fetch the data
            title = re.sub(r'\s+', ' ', find_pattern(txt, title_pat).strip())
            author = re.sub(r'\n+', ';', find_pattern(txt, auth_pat).strip())
            abstract = re.sub(r'\n+', '\n', find_pattern(txt, abs_pat).strip())
            abstract = re.sub(r'\s+', ' ', re.sub(r'-\n(\w+ *)', r'\1\n', abstract))
            # remove extra spaces, and remove page number
            body = re.sub(r'\n[\d]\n', '', re.sub(r'\n+', '\n', find_pattern(txt, body_pat).strip()))
            body = re.sub(r'\s+', ' ', re.sub(r'-\n(\w+ *)', r'\1\n', body))
        # end open
        # add to dictionary list
        text_dict_lst[i] = {"filename":file_n, "title":title, "author":author, "abstract":abstract, "body":body}
        i += 1
    # end for
        
    print(f"Successfully fetch {i} PDF files")
        
    return pd.DataFrame.from_dict(text_dict_lst, orient="index")

# %% [markdown]
# Save the generated dataframe into

# %%
df_t2 = read_pdf_text(get_dir_file())
print(df_t2.shape)
df_t2.head()
# Out:
# Successfully fetch 200 PDF files
# (200, 5)
#      filename                                              title  \
# 0  PP3167.pdf     Regularized Boost for Semi-Supervised Learning
# 1  PP3210.pdf  Conﬁguration Estimates Improve Pedestrian Finding
# 2  PP3213.pdf  Unconstrained On-line Handwriting Recognition ...
# 3  PP3248.pdf  Direct Importance Estimation with Model Select...
# 4  PP3285.pdf  Linear programming analysis of loopy belief pr...
#
#                                               author  \
# 0                                Ke Chen;Shihai Wang
# 1                         David A. Forsyth;Duan Tran
# 2  J?rgen Schmidhuber;Alex Graves;Marcus Liwicki;...
# 3  Masashi Sugiyama;Motoaki Kawanabe;Hisashi Kash...
# 4    Alan S. Willsky;Dmitry Malioutov;Sujay Sanghavi
#
#                                             abstract  \
# 0  Semi-supervised inductive learning concerns ho...
# 1  Fair discriminative pedestrian ﬁnders are now ...
# 2  On-line handwriting recognition is unusual amo...
# 3  When training and test samples follow diﬀerent...
# 4  Loopy belief propagation has been employed in ...
#
#                                                 body
# 0  Semi-supervised inductive learning concerns th...
# 1  Very accurate pedestrian detectors are an impo...
# 2  In online handwriting recognition the trajecto...
# 3  A common assumption in supervised learning is ...
# 4  Loopy Belief Propagation (LBP) and its variant...

# %% [markdown]
# Here, we just convert the dataframe to CSV file

# %%
# convert to csv file
df_t2.to_csv("result.csv", index = False)
# Out:
#   top10_items_in_abstract top10_items_in_title          top10_author
# 0                    data             learning    Bernhard Sch?lkopf
# 1                learning               models               Le Song
# 2                   model             networks        Lawrence Carin
# 3               algorithm               neural        Sujay Sanghavi
# 4                 problem               linear         Daniel D. Lee
# 5                    show                model  Pradeep K. Ravikumar
# 6                  models           stochastic          Doina Precup
# 7                  method         optimization     Zoubin Ghahramani
# 8                 methods            recurrent           Alex Graves
# 9                 results          application         David M. Blei
